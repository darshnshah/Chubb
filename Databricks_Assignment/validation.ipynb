-- %%
-- Validation notebook, to show each table created by the pipeline
-- Set the catalog and schema to simplify table references
USE CATALOG workspace;
USE SCHEMA `ny-taxi`;

SELECT current_catalog(), current_schema();
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th><th>current_schema()</th></tr></thead><tbody><tr><td>workspace</td><td>`ny-taxi`</td></tr></tbody></table></div>

-- %%
--to validate bronze layer ingestion table
-- Select 10 records from the raw data table
SELECT
  *
FROM
  taxi_raw_records 
LIMIT
  10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
-- Validating the first silver layer table, for flagged rides
-- Select 10 records from the cleaned/flagged data table
SELECT
  *
FROM
  flagged_rides 
LIMIT
  10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
--Validating the second silver layer table, the weekly rides
-- Select 10 records from the weekly aggregation table
-- Inspect aggregated columns to ensure the transformation logic worked
SELECT
  *
FROM
  weekly_stats 
LIMIT
  10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
-- And finally validating the gold layer table, top_n
-- Select 10 records from the top N analytical table
-- Ensure the results are correctly ordered and limited, should have 3 rows
SELECT
  *
FROM
  top_n;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>week</th><th>avg_amount</th><th>avg_distance</th><th>fare_amount</th><th>trip_distance</th><th>zip</th></tr></thead><tbody><tr><td>2016-01-04T00:00:00.000Z</td><td>11.91</td><td>2.865</td><td>95.0</td><td>5.2</td><td>10009</td></tr><tr><td>2016-02-15T00:00:00.000Z</td><td>12.24</td><td>2.894</td><td>60.0</td><td>2.0</td><td>7311</td></tr><tr><td>2016-02-22T00:00:00.000Z</td><td>12.79</td><td>2.973</td><td>60.0</td><td>0.92</td><td>11422</td></tr></tbody></table></div>
